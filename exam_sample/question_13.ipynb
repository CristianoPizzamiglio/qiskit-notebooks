# %%
from qiskit import QuantumCircuit, transpile

# %%
qc = QuantumCircuit(2, 2)

# %%
qc.h(0)
qc.barrier(0)
qc.cx(0, 1)
qc.barrier([0, 1])
qc.draw()

# %%
tqc = transpile(qc)
tqc.draw()

# %%
print(qc.depth())
print('\n')
print(tqc.depth())
# Out:
# 2
#
#
# 2
