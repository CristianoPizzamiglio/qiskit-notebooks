# %%
# This code is to create the interactive figure
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, CustomJS, Slider
from bokeh.plotting import figure, show
from bokeh.embed import file_html
from bokeh.resources import CDN
import numpy as np
import IPython

x = np.arange(0,500)
y_linear = x
y_sqrt = 7.5*np.sqrt(x)

linear_source = ColumnDataSource(data=dict(x=x, y=y_linear))
sqrt_source = ColumnDataSource(data=dict(x=x, y=y_sqrt))

plot = figure(
              plot_height=400, 
              plot_width=800,
              sizing_mode="scale_width",
              tools="reset,save",
              x_range=[0, 500], y_range=[0, 500], 
              x_axis_label="Size of Problem",
              y_axis_label="Time Taken to Find Solution")
plot.line('x', 'y', source=linear_source, line_width=3, line_alpha=0.6, color="blue", legend_label="Classical Search O(N)")
plot.line('x', 'y', source=sqrt_source, line_width=3, line_alpha=0.6, color="red", legend_label="Quantum Search O(√N)")
plot.legend.location = "top_left"

callback = CustomJS(args=dict(source=sqrt_source), code="""
        var data = source.data;
        var f = (10-cb_obj.value)*2 + 3
        var x = data['x']
        var y = data['y']
        for (var i = 0; i < x.length; i++) {
            y[i] = f*Math.sqrt(x[i])
        }
        source.change.emit();
    """)

speed_slider = Slider(title="Relative Speed of Quantum Computer", value=7.5, start=1.0, end=10.0, step=0.1, show_value=False)
speed_slider.js_on_change('value', callback)

layout = column(plot, speed_slider)

caption = """
Comparing performance of algorithms across different platforms is difficult. What we can tell (through big-O-notation) is 
despite the difference in speeds between our classical and quantum computers, for a large enough problem, the quantum search 
algorithm will always out-perform the classical search algorithm."""

html_repr = file_html(layout, CDN)
html_fig = "<figure>{0}<figcaption>{1}</figcaption></figure>".format(html_repr, caption)
IPython.display.HTML(html_fig)
# Out:
# <figure>
#
#
#
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#
#
#
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-2.4.2.min.js"></script>
#         <script type="text/javascript" src="https://cdn.bokeh.org/bokeh/release/bokeh-widgets-2.4.2.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="247e2d56-f545-4444-a6a1-dacafd63aaf1" data-root-id="1692"></div>
#
#
#
#
#
#         <script type="application/json" id="1837">
#           {"ab176cd1-653f-422d-8b13-33d02626b81d":{"defs":[],"roots":{"references":[{"attributes":{"end":10.0,"js_property_callbacks":{"change:value":[{"id":"1690"}]},"show_value":false,"start":1.0,"step":0.1,"title":"Relative Speed of Quantum Computer","value":7.5},"id":"1691","type":"Slider"},{"attributes":{"coordinates":null,"group":null},"id":"1659","type":"Title"},{"attributes":{"line_alpha":0.1,"line_color":"red","line_width":3,"x":{"field":"x"},"y":{"field":"y"}},"id":"1673","type":"Line"},{"attributes":{},"id":"1666","type":"AllLabels"},{"attributes":{"children":[{"id":"1631"},{"id":"1691"}]},"id":"1692","type":"Column"},{"attributes":{"line_alpha":0.6,"line_color":"red","line_width":3,"x":{"field":"x"},"y":{"field":"y"}},"id":"1672","type":"Line"},{"attributes":{"line_alpha":0.2,"line_color":"red","line_width":3,"x":{"field":"x"},"y":{"field":"y"}},"id":"1674","type":"Line"},{"attributes":{"label":{"value":"Quantum Search O(\u221aN)"},"renderers":[{"id":"1675"}]},"id":"1689","type":"LegendItem"},{"attributes":{"end":500},"id":"1632","type":"Range1d"},{"attributes":{"source":{"id":"1630"}},"id":"1676","type":"CDSView"},{"attributes":{"coordinates":null,"data_source":{"id":"1630"},"glyph":{"id":"1672"},"group":null,"hover_glyph":null,"muted_glyph":{"id":"1674"},"nonselection_glyph":{"id":"1673"},"view":{"id":"1676"}},"id":"1675","type":"GlyphRenderer"},{"attributes":{"args":{"source":{"id":"1630"}},"code":"\n        var data = source.data;\n        var f = (10-cb_obj.value)*2 + 3\n        var x = data['x']\n        var y = data['y']\n        for (var i = 0; i &lt; x.length; i++) {\n            y[i] = f*Math.sqrt(x[i])\n        }\n        source.change.emit();\n    "},"id":"1690","type":"CustomJS"},{"attributes":{},"id":"1648","type":"ResetTool"},{"attributes":{"axis":{"id":"1644"},"coordinates":null,"dimension":1,"group":null,"ticker":null},"id":"1647","type":"Grid"},{"attributes":{},"id":"1638","type":"LinearScale"},{"attributes":{},"id":"1688","type":"Selection"},{"attributes":{"axis_label":"Time Taken to Find Solution","coordinates":null,"formatter":{"id":"1662"},"group":null,"major_label_policy":{"id":"1663"},"ticker":{"id":"1645"}},"id":"1644","type":"LinearAxis"},{"attributes":{},"id":"1636","type":"LinearScale"},{"attributes":{"coordinates":null,"group":null,"items":[{"id":"1670"},{"id":"1689"}],"location":"top_left"},"id":"1669","type":"Legend"},{"attributes":{"source":{"id":"1629"}},"id":"1658","type":"CDSView"},{"attributes":{},"id":"1667","type":"UnionRenderers"},{"attributes":{"data":{"x":{"__ndarray__":"...","dtype":"int32","order":"little","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","order":"little","shape":[500]}},"selected":{"id":"1688"},"selection_policy":{"id":"1687"}},"id":"1630","type":"ColumnDataSource"},{"attributes":{},"id":"1663","type":"AllLabels"},{"attributes":{"line_alpha":0.6,"line_color":"blue","line_width":3,"x":{"field":"x"},"y":{"field":"y"}},"id":"1654","type":"Line"},{"attributes":{"axis_label":"Size of Problem","coordinates":null,"formatter":{"id":"1665"},"group":null,"major_label_policy":{"id":"1666"},"ticker":{"id":"1641"}},"id":"1640","type":"LinearAxis"},{"attributes":{"axis":{"id":"1640"},"coordinates":null,"group":null,"ticker":null},"id":"1643","type":"Grid"},{"attributes":{"data":{"x":{"__ndarray__":"...","dtype":"int32","order":"little","shape":[500]},"y":{"__ndarray__":"...","dtype":"int32","order":"little","shape":[500]}},"selected":{"id":"1668"},"selection_policy":{"id":"1667"}},"id":"1629","type":"ColumnDataSource"},{"attributes":{"end":500},"id":"1634","type":"Range1d"},{"attributes":{},"id":"1649","type":"SaveTool"},{"attributes":{},"id":"1645","type":"BasicTicker"},{"attributes":{},"id":"1641","type":"BasicTicker"},{"attributes":{},"id":"1662","type":"BasicTickFormatter"},{"attributes":{"tools":[{"id":"1648"},{"id":"1649"}]},"id":"1650","type":"Toolbar"},{"attributes":{"coordinates":null,"data_source":{"id":"1629"},"glyph":{"id":"1654"},"group":null,"hove ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             const fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   const docs_json = document.getElementById('1837').textContent;
#                   const render_items = [{"docid":"ab176cd1-653f-422d-8b13-33d02626b81d","root_ids":["1692"],"roots":{"1692":"247e2d56-f545-4444-a6a1-dacafd63aaf1"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     let attempts = 0;
#                     const timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         clearInterval(timer);
#                         embed_document(root);
#                       } else {
#                         attempts++;
#                         if (attempts > 100) {
#                           clearInterval(timer);
#                           console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         }
#                       }
#                     }, 10, root)
#                   }
#                 })(window);
#               });
#             };
#             if (document.readyState != "loading") fn();
#             else document.addEventListener("DOMContentLoaded", fn);
#           })();
#         </script>
#
#   </body>
#
# </html><figcaption>
# Comparing performance of algorithms across different platforms is difficult. What we can tell (through big-O-notation) is
# despite the difference in speeds between our classical and quantum computers, for a large enough problem, the quantum search
# algorithm will always out-perform the classical search algorithm.</figcaption></figure>
